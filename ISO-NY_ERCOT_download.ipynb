# %%
import os
import requests
import pandas as pd
from bs4 import BeautifulSoup
from io import StringIO

# %% [markdown]
# ## ISO-NY and ERCOT vibe programming

# %%
# Define the URL for the 2023 NYISO Day-Ahead LMP data
url = "https://www.eia.gov/electricity/wholesalemarkets/csv/nyiso_lmp_da_hr_zones_2023.csv"

# Create a directory to save the data
save_dir = "nyiso_data"
os.makedirs(save_dir, exist_ok=True)

# Define the path to save the CSV file
file_path = os.path.join(save_dir, "nyiso_lmp_da_hr_zones_2023.csv")

# Download the CSV file
print(f"🔍 Attempting to download data from {url}")
response = requests.get(url)
if response.status_code == 200:
    with open(file_path, "wb") as f:
        f.write(response.content)
    print(f"✅ Data successfully saved to {file_path}")
else:
    print(f"❌ Failed to download data. Status code: {response.status_code}")

# Optional: Load and display the first few rows of the data
try:
    df = pd.read_csv(file_path)
    print("📊 Preview of the downloaded data:")
    print(df.head())
except Exception as e:
    print(f"⚠️ An error occurred while reading the CSV file: {e}")
# Out:
# 🔍 Attempting to download data from https://www.eia.gov/electricity/wholesalemarkets/csv/nyiso_lmp_da_hr_zones_2023.csv
# ✅ Data successfully saved to nyiso_data/nyiso_lmp_da_hr_zones_2023.csv
# ⚠️ An error occurred while reading the CSV file: Error tokenizing data. C error: Expected 1 fields in line 4, saw 38

# %%
# --------------------------
# STEP 1: Load and Clean Data
# --------------------------

# Path to the CSV file (replace with your own file path if needed)
file_path = "nyiso_data/nyiso_lmp_da_hr_zones_2023.csv"

# Skip the first 3 metadata rows, parse dates
df = pd.read_csv(file_path, skiprows=3)

# Convert Local Date to datetime format
df['Local Date'] = pd.to_datetime(df['Local Date'])

# --------------------------
# STEP 2: Filter for 2023 to Present
# --------------------------
df = df[df['Local Date'] >= '2023-01-01']

# --------------------------
# STEP 3: Select Zone LMP Columns
# --------------------------
# Note: Columns 5 to 15 contain LMPs for Zones A–K (based on structure from preview)
lmp_columns = [
    'A - West LMP', 'B - Genessee LMP', 'C - Central LMP', 'D - North LMP',
    'E - Mohawk Valley LMP', 'F - Capital LMP', 'G - Hudson Valley LMP',
    'H - Millwood LMP', 'I - Dunwoodie LMP', 'J - New York City LMP', 'K - Long Island LMP'
]

# Set index for time-based resampling
df.set_index('Local Date', inplace=True)

# --------------------------
# STEP 4: Resample Quarterly and Aggregate
# --------------------------
# Calculate quarterly average LMPs
quarterly_lmp = df[lmp_columns].resample('Q').mean()

# --------------------------
# STEP 5: Save or Display Results
# --------------------------
# Option 1: Display as a table
print("Quarterly Average LMPs for ISO-NY (2023–Present):")
print(quarterly_lmp)

# Option 2: Save to a CSV file
quarterly_lmp.to_csv("nyiso_quarterly_LMP_averages.csv")
# Out:
# Quarterly Average LMPs for ISO-NY (2023–Present):
#             A - West LMP  B - Genessee LMP  C - Central LMP  D - North LMP  \
# Local Date
# 2023-03-31     27.168958         28.231000        29.929328      25.662214
# 2023-06-30     19.971639         20.157711        20.834418      18.401658
# 2023-09-30     32.848649         32.929444        33.374268      32.248876
# 2023-12-31     26.686222         26.764671        27.621269      25.326964
#
#             E - Mohawk Valley LMP  F - Capital LMP  G - Hudson Valley LMP  \
# Local Date
# 2023-03-31              30.803881        50.129430              42.091834
# 2023-06-30              21.244290        29.697436              27.129849
# 2023-09-30              34.280960        38.640038              36.757386
# 2023-12-31              28.445845        33.011626              31.999057
#
#             H - Millwood LMP  I - Dunwoodie LMP  J - New York City LMP  \
# Local Date
# 2023-03-31         42.492557          42.468050              42.567698
# 2023-06-30         27.416511          27.491026              27.619048
# 2023-09-30         37.417109          37.559495              37.813750
# 2023-12-31         32.439132          32.546468              32.700065
#
#             K - Long Island LMP
# Local Date
# 2023-03-31            51.786786
# 2023-06-30            30.688860
# 2023-09-30            49.579508
# 2023-12-31            38.302750
# /var/folders/d_/m7d57y8503v9gkg60n1d213h0000gn/T/ipykernel_7923/506036813.py:36: FutureWarning: 'Q' is deprecated and will be removed in a future version, please use 'QE' instead.
#   quarterly_lmp = df[lmp_columns].resample('Q').mean()

# %%
data_dir = Path("/Users/alanwang/STAT390/nyiso_data")  
csv_files = list(data_dir.glob("nyiso_lmp_da_hr_zones_*.csv"))

output_dir = data_dir / "quarterly_outputs"
output_dir.mkdir(exist_ok=True)

for file in csv_files:
    print(f"📄 Processing {file.name}")
    try:
        df = pd.read_csv(file, skiprows=3)

        # Parse datetime from 'Local Date'
        df['Local Date'] = pd.to_datetime(df['Local Date'])
        df['Quarter'] = df['Local Date'].dt.to_period('Q').astype(str)

        # Filter for LMP columns only (exclude Congestion/Loss)
        lmp_cols = [col for col in df.columns if 'LMP' in col and 'Congestion' not in col and 'Loss' not in col]
        selected_cols = ['Local Date', 'Quarter'] + lmp_cols

        df = df[selected_cols]

        # Split and write each quarter to its own file
        for quarter, group in df.groupby('Quarter'):
            filename = f"NYISO_LMP_{quarter}.csv"
            group.drop(columns='Quarter').to_csv(output_dir / filename, index=False)
            print(f"✅ Saved: {filename}")

    except Exception as e:
        print(f"⚠️ Failed to process {file.name}: {e}")
# Out:
# 📄 Processing nyiso_lmp_da_hr_zones_2025.csv
# ✅ Saved: NYISO_LMP_2025Q1.csv
# ✅ Saved: NYISO_LMP_2025Q2.csv
# 📄 Processing nyiso_lmp_da_hr_zones_2024.csv
# ✅ Saved: NYISO_LMP_2024Q1.csv
# ✅ Saved: NYISO_LMP_2024Q2.csv
# ✅ Saved: NYISO_LMP_2024Q3.csv
# ✅ Saved: NYISO_LMP_2024Q4.csv
# 📄 Processing nyiso_lmp_da_hr_zones_2023.csv
# ✅ Saved: NYISO_LMP_2023Q1.csv
# ✅ Saved: NYISO_LMP_2023Q2.csv
# ✅ Saved: NYISO_LMP_2023Q3.csv
# ✅ Saved: NYISO_LMP_2023Q4.csv
# 📄 Processing nyiso_lmp_da_hr_zones_2022.csv
# ✅ Saved: NYISO_LMP_2022Q1.csv
# ✅ Saved: NYISO_LMP_2022Q2.csv
# ✅ Saved: NYISO_LMP_2022Q3.csv
# ✅ Saved: NYISO_LMP_2022Q4.csv

# %%
print(f"🧠 Columns in {file.name}: {df.columns.tolist()}")
# Out:
# 🧠 Columns in nyiso_lmp_da_hr_zones_2022.csv: ['UTC Timestamp (Interval Ending)', 'Local Timestamp Eastern Time (Interval Beginning)', 'Local Timestamp Eastern Time (Interval Ending)', 'Local Date', 'Hour Number', 'A - West LMP', 'B - Genessee LMP', 'C - Central LMP', 'D - North LMP', 'E - Mohawk Valley LMP', 'F - Capital LMP', 'G - Hudson Valley LMP', 'H - Millwood LMP', 'I - Dunwoodie LMP', 'J - New York City LMP', 'K - Long Island LMP', 'A - West (Congestion)', 'B - Genessee (Congestion)', 'C - Central (Congestion)', 'D - North (Congestion)', 'E - Mohawk Valley (Congestion)', 'F - Capital (Congestion)', 'G - Hudson Valley (Congestion)', 'H - Millwood (Congestion)', 'I - Dunwoodie (Congestion)', 'J - New York City (Congestion)', 'K - Long Island (Congestion)', 'A - West (Loss)', 'B - Genessee (Loss)', 'C - Central (Loss)', 'D - North (Loss)', 'E - Mohawk Valley (Loss)', 'F - Capital (Loss)', 'G - Hudson Valley (Loss)', 'H - Millwood (Loss)', 'I - Dunwoodie (Loss)', 'J - New York City (Loss)', 'K - Long Island (Loss)']

# %% [markdown]
# # ercot

# %%
import requests
import pandas as pd
from io import BytesIO
from zipfile import ZipFile
import os

# ------------------ 🔐 Replace with YOUR INFO -------------------
USERNAME = "alanwang2025@u.northwestern.edu"
PASSWORD = "Fork102$"  # <<< Replace with your actual password
SUBSCRIPTION_KEY = "7076e411aeeb461e8bb085df1690f0cd"  # Your ERCOT Primary Key
# ---------------------------------------------------------------

# Step 1: Authenticate to get an ID Token
print("🔑 Authenticating...")
token_url = "https://ercotb2c.b2clogin.com/ercotb2c.onmicrosoft.com/B2C_1_PUBAPI-ROPC-FLOW/oauth2/v2.0/token"

token_data = {
    "grant_type": "client_credentials",
    "scope": "openid fec253ea-0d06-4272-a5e6-b478baeecd70 offline_access",
    "client_id": "fec253ea-0d06-4272-a5e6-b478baeecd70",
    "username": "alanwang2025@u.northwestern.edu",
    "password": "Fork10$",
    "response_type": "id_token"
}

response = requests.post(token_url, data=token_data)
response.raise_for_status()
id_token = response.json()["id_token"]
print("✅ Token received.")

# Step 2: Access the NP4-183-CD report endpoint
headers = {
    "Authorization": f"Bearer {id_token}",
    "Ocp-Apim-Subscription-Key": SUBSCRIPTION_KEY
}

print("📦 Accessing ERCOT API for DAM Hourly LMPs...")
report_endpoint = "https://api.ercot.com/api/public-reports/np4-183-cd"
r = requests.get(report_endpoint, headers=headers)
r.raise_for_status()
print(response.json())
artifacts = r.json()["_embedded"]["artifacts"]

# Step 3: Download and extract ZIPs
output_dir = "ercot_quarterly_outputs"
os.makedirs(output_dir, exist_ok=True)

for artifact in artifacts:
    download_url = artifact["_links"]["endpoint"]["href"]
    print(f"⬇️ Downloading: {download_url}")
    zip_r = requests.get(download_url, headers=headers)
    if zip_r.status_code == 200:
        with ZipFile(BytesIO(zip_r.content)) as z:
            for file_info in z.infolist():
                if file_info.filename.endswith(".csv"):
                    with z.open(file_info) as f:
                        try:
                            df = pd.read_csv(f)
                            df["Delivery Date"] = pd.to_datetime(df["Delivery Date"])
                            df["Quarter"] = df["Delivery Date"].dt.to_period("Q").astype(str)
                            for quarter, group in df.groupby("Quarter"):
                                out_path = os.path.join(output_dir, f"ERCOT_LMP_{quarter}.csv")
                                if os.path.exists(out_path):
                                    group.to_csv(out_path, mode='a', header=False, index=False)
                                else:
                                    group.to_csv(out_path, index=False)
                        except Exception as e:
                            print(f"❌ Error processing {file_info.filename}: {e}")
    else:
        print(f"⚠️ Failed to download {download_url}")
# Out:
# 🔑 Authenticating...
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[1], line 27
#      17 token_data = {
#      18     "grant_type": "client_credentials",
#      19     "scope": "openid fec253ea-0d06-4272-a5e6-b478baeecd70 offline_access",
#    (...)
#      23     "response_type": "id_token"
#      24 }
#      26 response = requests.post(token_url, data=token_data)
# ---> 27 response.raise_for_status()
#      28 id_token = response.json()["id_token"]
#      29 print("✅ Token received.")
#
# File ~/miniconda3/lib/python3.12/site-packages/requests/models.py:1024, in Response.raise_for_status(self)
#    1019     http_error_msg = (
#    1020         f"{self.status_code} Server Error: {reason} for url: {self.url}"
#    1021     )
#    1023 if http_error_msg:
# -> 1024     raise HTTPError(http_error_msg, response=self)
#
# HTTPError: 400 Client Error: Bad Request for url: https://ercotb2c.b2clogin.com/ercotb2c.onmicrosoft.com/B2C_1_PUBAPI-ROPC-FLOW/oauth2/v2.0/token

# %%
import requests

token_url = "https://ercotb2c.b2clogin.com/ercotb2c.onmicrosoft.com/B2C_1_PUBAPI-ROPC-FLOW/oauth2/v2.0/token"

headers = {
    "Content-Type": "application/x-www-form-urlencoded"
}

token_data = {
    "grant_type": "password",
    "scope": "openid fec253ea-0d06-4272-a5e6-b478baeecd70 offline_access",
    "client_id": "fec253ea-0d06-4272-a5e6-b478baeecd70",
    "username": "alanwang2025@u.northwestern.edu",
    "password": "Fork102$"
}

response = requests.post(token_url, data=token_data, headers=headers)
response.raise_for_status()
access_token = response.json()["access_token"]
print("✅ Token received.")
# Out:
# ✅ Token received.

# %%
import base64
import json

token_parts = access_token.split(".")
payload = token_parts[1] + '=' * (-len(token_parts[1]) % 4)  # fix padding
decoded = json.loads(base64.urlsafe_b64decode(payload.encode()).decode())
print(json.dumps(decoded, indent=2))
# Out:
# {
#   "aud": "fec253ea-0d06-4272-a5e6-b478baeecd70",
#   "iss": "https://ercotb2c.b2clogin.com/6df17afa-1b36-499a-83f7-56779ad0b9a6/v2.0/",
#   "exp": 1745532246,
#   "nbf": 1745528646,
#   "idp": "LocalAccount",
#   "oid": "8de9998e-1bce-4aa0-91c4-9dd4d264f0cd",
#   "sub": "8de9998e-1bce-4aa0-91c4-9dd4d264f0cd",
#   "given_name": "Alan",
#   "family_name": "Wang",
#   "emails": [
#     "alanwang2025@u.northwestern.edu"
#   ],
#   "tfp": "B2C_1_PUBAPI-ROPC-FLOW",
#   "azp": "fec253ea-0d06-4272-a5e6-b478baeecd70",
#   "ver": "1.0",
#   "iat": 1745528646
# }

# %%
access_token
# Out:
# 'eyJhbGciOiJSUzI1NiIsImtpZCI6Ilg1ZVhrNHh5b2pORnVtMWtsMll0djhkbE5QNC1jNTdkTzZRR1RWQndhTmsiLCJ0eXAiOiJKV1QifQ.....RRgGe-dPmxvUjJPQ8Xt2xHS2Zh_l3gXwm0R7JQ-sGpINh9tHpFUadfNHJcdQ1_A2pRQYW-H8gS51q737xtT5uRXoIpGZfovJLnIADRTDSzg-bG9YJPAX206d8S5VrKOiMPDFyiyMRnqHl8YoiVM-EywnwenJ-Npp2VpI2wkgDI1q98670ou3S5ZwYpeA_zzjgh66sSNQhI_-iMGIO_vBlsdTrPgqo_aF91EO5XJMbV8rABaB6BmKBE0cYubC3QOG994tJduhTuM4mWw_5VvFq28BTtWcYVVMu77U5QnT5RCfb-_l5FOCluJO8cakFjZlF8FfeP7BOI-RjREK1Ehl3g'

# %%
import requests
import pandas as pd
import os
import time
from io import StringIO
from zipfile import ZipFile
from datetime import datetime as dt

# Replace with your real token and subscription key
subscription_key = "7076e411aeeb461e8bb085df1690f0cd"


# Headers for API access
headers = {
    "Authorization": f"Bearer {access_token}",
    "Ocp-Apim-Subscription-Key": subscription_key
}

# Step 1: Fetch archive metadata
print("📦 Fetching ERCOT DAM LMP archive list...")
endpoint = "https://api.ercot.com/api/public-reports/archive/np4-183-cd"
response = requests.get(endpoint, headers=headers)
response.raise_for_status()
archives = response.json().get("archives", [])
print(f"✅ Found {len(archives)} archive entries.")

# ✅ Filter for only archives from 2022 onwards
archives = [
    archive for archive in archives
    if "postDatetime" in archive and
       dt.fromisoformat(archive["postDatetime"][:19]) >= dt(2022, 1, 1) and
       dt.fromisoformat(archive["postDatetime"][:19]) <= dt(2025, 12, 31)
]

print(f"✅ Found {len(archives)} archive entries from 2022 onward.")

# Output dir
output_dir = "ercot_dam_outputs"
os.makedirs(output_dir, exist_ok=True)

# Step 2: Download and parse
for i, archive in enumerate(archives):
    download_url = f"https://api.ercot.com/api/public-reports/archive/np4-183-cd?download={archive['docId']}"
    print(f"\n⬇️ Downloading ({i+1}): {archive['friendlyName']}")
    
    for _ in range(3):
        r = requests.get(download_url, headers=headers)
        if r.status_code == 429:
            print("⏳ Rate limit hit. Waiting...")
            time.sleep(2)
        else:
            break

    if r.status_code != 200:
        print(f"⚠️ Failed to download. Status: {r.status_code}")
        continue

    content_type = r.headers.get("Content-Type", "")
    raw = r.content

    try:
        if raw.startswith(b'PK'):  # ZIP magic number
            print("📦 Detected ZIP archive")
            with ZipFile(BytesIO(raw)) as z:
                for file_info in z.infolist():
                    if file_info.filename.endswith(".csv"):
                        with z.open(file_info) as f:
                            df = pd.read_csv(f, engine='python', on_bad_lines='skip')
        else:
            print("🧾 Detected raw CSV file")
            decoded = raw.decode("utf-8", errors="ignore")
            df = pd.read_csv(StringIO(decoded), engine='python', on_bad_lines='skip')

        # Normalize column names
        df.columns = df.columns.str.strip().str.lower().str.replace(" ", "")
        print("📑 Columns:", df.columns.tolist())

        # Accept 'deliverydate' or fallback options
        date_col = None
        for col in df.columns:
            if col in ["deliverydate", "delivery_date", "delvdate"]:
                date_col = col
                break

        if not date_col:
            print(f"❌ No recognized delivery date column in: {archive['friendlyName']}")
            continue

        df[date_col] = pd.to_datetime(df[date_col], errors="coerce")
        df["quarter"] = df[date_col].dt.to_period("Q").astype(str)

        for quarter, group in df.groupby("quarter"):
            out_path = os.path.join(output_dir, f"ERCOT_LMP_{quarter}.csv")
            if os.path.exists(out_path):
                group.to_csv(out_path, mode='a', header=False, index=False)
            else:
                group.to_csv(out_path, index=False)
        
        print(f"✅ Saved: {archive['friendlyName']}")
    except Exception as e:
        print(f"❌ Error parsing {archive['friendlyName']}: {e}")
# Out:
# 📦 Fetching ERCOT DAM LMP archive list...
# ✅ Found 1000 archive entries.
# ✅ Found 1000 archive entries from 2022 onward.
#
# ⬇️ Downloading (1): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (2): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (3): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (4): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (5): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (6): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (7): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (8): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (9): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (10): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (11): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (12): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (13): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (14): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (15): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (16): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (17): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (18): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (19): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (20): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (21): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (22): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (23): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (24): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (25): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (26): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (27): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (28): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (29): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (30): DAMHRLMPNP4183_csv
# ⏳ Rate limit hit. Waiting...
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (31): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (32): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (33): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (34): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (35): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (36): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (37): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (38): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (39): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (40): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (41): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (42): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (43): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (44): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (45): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (46): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (47): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (48): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (49): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (50): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (51): DAMHRLMPNP4183_csv
# ⏳ Rate limit hit. Waiting...
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (52): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (53): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (54): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (55): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (56): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (57): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (58): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (59): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (60): DAMHRLMPNP4183_csv
# ⏳ Rate limit hit. Waiting...
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (61): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (62): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (63): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (64): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (65): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (66): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (67): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (68): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (69): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (70): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (71): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (72): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (73): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (74): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (75): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (76): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (77): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (78): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (79): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (80): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (81): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (82): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (83): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (84): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (85): DAMHRLMPNP4183_csv
# ⏳ Rate limit hit. Waiting...
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (86): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (87): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (88): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (89): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (90): DAMHRLMPNP4183_csv
# ⏳ Rate limit hit. Waiting...
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (91): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (92): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (93): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (94): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (95): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (96): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (97): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (98): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (99): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (100): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (101): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (102): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (103): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (104): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (105): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (106): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (107): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (108): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (109): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (110): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (111): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (112): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (113): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (114): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (115): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (116): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (117): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (118): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (119): DAMHRLMPNP4183_csv
# ⏳ Rate limit hit. Waiting...
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (120): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (121): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (122): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (123): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (124): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (125): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (126): DAMHRLMPNP4183_csv
# ⏳ Rate limit hit. Waiting...
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (127): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (128): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (129): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (130): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (131): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (132): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (133): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (134): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (135): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (136): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (137): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (138): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (139): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (140): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (141): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (142): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (143): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (144): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (145): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (146): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (147): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (148): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (149): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (150): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (151): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (152): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (153): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (154): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (155): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (156): DAMHRLMPNP4183_csv
# ⏳ Rate limit hit. Waiting...
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (157): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (158): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (159): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (160): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (161): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (162): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (163): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (164): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (165): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (166): DAMHRLMPNP4183_csv
# ⏳ Rate limit hit. Waiting...
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (167): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (168): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (169): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (170): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (171): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (172): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (173): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (174): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (175): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (176): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (177): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (178): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (179): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (180): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (181): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (182): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (183): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (184): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (185): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (186): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (187): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (188): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (189): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (190): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (191): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (192): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (193): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (194): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (195): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (196): DAMHRLMPNP4183_csv
# ⏳ Rate limit hit. Waiting...
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (197): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (198): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (199): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (200): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (201): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (202): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (203): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (204): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (205): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (206): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (207): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (208): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (209): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (210): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (211): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (212): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (213): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (214): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (215): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (216): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (217): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (218): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (219): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (220): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (221): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (222): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (223): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (224): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (225): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (226): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (227): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (228): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (229): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (230): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (231): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (232): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (233): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (234): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (235): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (236): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (237): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (238): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (239): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (240): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (241): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (242): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (243): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (244): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (245): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (246): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (247): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (248): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (249): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (250): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (251): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (252): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (253): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (254): DAMHRLMPNP4183_csv
# ⏳ Rate limit hit. Waiting...
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (255): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (256): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (257): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (258): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (259): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (260): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (261): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (262): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (263): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (264): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (265): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (266): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (267): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (268): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (269): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (270): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (271): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (272): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (273): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (274): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (275): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (276): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (277): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (278): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (279): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (280): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (281): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (282): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (283): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (284): DAMHRLMPNP4183_csv
# ⏳ Rate limit hit. Waiting...
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (285): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (286): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (287): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (288): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (289): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (290): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (291): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# ...
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (905): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (906): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (907): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (908): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (909): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (910): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (911): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (912): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (913): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (914): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (915): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (916): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (917): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (918): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (919): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (920): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (921): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (922): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (923): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (924): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (925): DAMHRLMPNP4183_csv
# ⏳ Rate limit hit. Waiting...
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (926): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (927): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (928): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (929): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (930): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (931): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (932): DAMHRLMPNP4183_csv
# ⏳ Rate limit hit. Waiting...
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (933): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (934): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (935): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (936): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (937): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (938): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (939): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (940): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (941): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (942): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (943): DAMHRLMPNP4183_csv
# ⏳ Rate limit hit. Waiting...
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (944): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (945): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (946): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (947): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (948): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (949): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (950): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (951): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (952): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (953): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (954): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (955): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (956): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (957): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (958): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (959): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (960): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (961): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (962): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (963): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (964): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (965): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (966): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (967): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (968): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (969): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (970): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (971): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (972): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (973): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (974): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (975): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (976): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (977): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (978): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (979): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (980): DAMHRLMPNP4183_csv
# ⏳ Rate limit hit. Waiting...
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (981): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (982): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (983): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (984): DAMHRLMPNP4183_csv
# ⏳ Rate limit hit. Waiting...
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (985): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (986): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (987): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (988): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (989): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (990): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (991): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (992): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (993): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (994): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (995): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (996): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (997): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (998): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (999): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
#
# ⬇️ Downloading (1000): DAMHRLMPNP4183_csv
# 📦 Detected ZIP archive
# 📑 Columns: ['deliverydate', 'hourending', 'busname', 'lmp', 'dstflag']
# ✅ Saved: DAMHRLMPNP4183_csv
